# %%
from flask import Flask, jsonify, redirect, request
from flask_cors import CORS
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from konlpy.tag import Okt
import json

#커스텀 모델 호출을 위한 함수 선언
from keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림 - 0.5 이하 = 0 / 0.5 초과 = 1
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정
    # True Positive = 실제 값과 예측 값이 모두 1(Positive)인 경우
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 
    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)
    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon() = 'divide by zero error' 예방차원에서 작은 수를 더함
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())
    # return a single tensor value
    return recall
def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림 - 0.5 이하 = 0 / 0.5 초과 = 1
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정
    # True Positive = 실제 값과 예측 값이 모두 1(Positive)인 경우
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 
    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)
    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon() = 'divide by zero error' 예방차원에서 작은 수를 더함
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())
    # return a single tensor value
    return precision
def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon() = divide by zero error' 예방차원에서 작은 수를 더함
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    # return a single tensor value
    return _f1score

# Server
app = Flask(__name__)
cors = CORS(app)
app.config['CORS_HEADERS'] = 'Content-Type'

# 문장 및 사용될 단어의 최대 길이/갯수 설정
maxlen = 50
max_words = 10000
# 생성된 형태소 배열 토큰화 및 정수 인코딩
tokenizer = Tokenizer(num_words=max_words)
with open('wordIndex.json') as json_file:
	word_index = json.load(json_file)
	tokenizer.word_index = word_index
tokenizer.fit_on_texts(word_index) # 빈도수 기준으로 단어 집합 생성
    
# 여기다 모델 3개 로딩예정
model_c1 = load_model('model_c1.h5', custom_objects = {"precision": precision, "recall" : recall, "f1score" : f1score})
model_c2 = load_model('model_c2.h5', custom_objects = {"precision": precision, "recall" : recall, "f1score" : f1score})
#model3 = load_model('model_c3.h5', custom_objects = {"precision": precision, "recall" : recall, "f1score" : f1score})


# Ai Function 
@app.route("/use_model", methods=['POST'])
def use_model():
	# Chrome Extension으로부터 전송받은 데이터
	examples_temp = request.get_json()
	examples = examples_temp["text"]
	check = examples_temp["check"]  # check[0] ~ [2] = 욕설, 비속어, 성적표현
	c1 = float(check[0] == True)
	c2 = float(check[1] == True)
	print(check)
	okt = Okt()
	ex_morpheme = []
	# 문장 형태소 분석
	for text in examples:
		mor_data = ""
		for word_tag in okt.pos(text, norm=True, stem=True):
			if word_tag[1] in ['Noun', 'Verb', 'VerbPrefix', 'Adjective', 'Determiner', 'Adverb', 'Exclamation', 'KoreanParticle']:
				mor_data += word_tag[0]
				mor_data += " "
		ex_morpheme.append(mor_data)
	sequences = tokenizer.texts_to_sequences(ex_morpheme) # 단어 빈도수가 높은 순으로 번호 부여
	# 문장 별 길이를 동일하게 맞추기 위한 패딩
	x_test = pad_sequences(sequences, maxlen=maxlen)
	
    #데이터로부터 욕설 가능성 계산 후 반환
	prob_c1 = model_c1.predict(x_test)
	prob_c2 = model_c2.predict(x_test)
    #prob_c1 = model_c1.predict(x_test)
    
    #데이터 값 저장 코드 추가
	labels_c1 = [] #욕설 데이터 값 저장용
	for i in range(0, len(x_test)):
		labels_c1.extend([round(prob_c1[i][0] * 100, 1)])
        
	labels_c2 = [] #욕설 데이터 값 저장용
	for i in range(0, len(x_test)):
		labels_c2.extend([round(prob_c2[i][0] * 100, 1)])
    
    #확률 계산
	prob_check = []
	print(labels_c1[0].dtype)
	for i in range(0, len(x_test)):
		prob_check.extend([max(labels_c1[i]*c1, labels_c2[i]*c2)])
		#prob_check[i]=max(labels_c1[i]*c1, labels_c2[i]*c2, label_c3[i]*c3):   대체예정
	for i in range(0, len(x_test)):
		print(examples[i], ":", prob_check[i], "%의 확률로 필터링 대상입니다.")            
	prob_json = { "prob": []}
	for i in range(0, len(x_test)):
		prob_json["prob"].append(float(prob_check[i]))
	return prob_json

# Server address
if __name__ == "__main__":
	app.run(host="127.0.0.1", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [True, True, True]
# float64
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# [if IE 7]>
# 	<link rel="stylesheet" type="text/css" href="//nstatic.dcinside.com/dc/w/css/ie7.css"/>
# 	<![endif] : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# [if lt IE 9]>
# 	<script src="//nstatic.dcinside.com/dgn/gallery/js/jquery-1.7.2.min.js"></script>
# 	<![endif] : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# [if gte IE 9]>
# 	<script src="//nstatic.dcinside.com/dgn/gallery/js/jquery-3.2.1.min.js"></script>
# 	<![endif] : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# [if !IE]>  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  <![endif] : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  Taboola  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  Taboola  : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
# 속보)고버지 좆됐다; .real - 리그 오브 레전드 : 96.6 %의 확률로 필터링 대상입니다.
#
# 		document.domain = "dcinside.com";
# 		var k_cnt = 0;
# 		var _GALLERY_TYPE_ = "G";
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#       window._taboola = window._taboola || [];
#       _taboola.push({category:'auto'});
#       !function (e, f, u, i) {
#         if (!document.getElementById(i)){
#           e.async = 1;
#           e.src = u;
#           e.id = i;
#           f.parentNode.insertBefore(e, f);
#         }
#       }(document.createElement('script'),
#       document.getElementsByTagName('script')[0],
#       '//cdn.taboola.com/libtrc/dcinside/loader.js',
#       'tb_loader_script');
#       if(window.performance && typeof window.performance.mark == 'function')
#       {window.performance.mark('tbl_ic');}
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
# 스킵 내비게이션 : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#  //스킵 내비게이션 : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  디시콘 정보 레이어팝업	 : 21.1 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //디시콘 정보 레이어팝업  : 21.1 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#  한줄 알림  : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#  //한줄 알림  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
#        : 22.2 %의 확률로 필터링 대상입니다.
#  Taboola  : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#  Taboola  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#  //180726 추가 wrap_inner : 21.4 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  기본 애널리틱스  : 53.8 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //기본 애널리틱스  : 53.8 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  추가 애널리틱스  : 60.5 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	<script type="text/javascript">
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-5149721-64']);
# 	  _gaq.push(['_setDomainName', 'dcinside.com']);
# 	  _gaq.push(['_setAllowLinker', true]);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  추가 애널리틱스  : 60.5 %의 확률로 필터링 대상입니다.
#
#
#
#
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
# 통합검색 바로가기 : 34.2 %의 확률로 필터링 대상입니다.
# 본문영역 바로가기 : 21.5 %의 확률로 필터링 대상입니다.
# 상단 메뉴 바로가기 : 22.6 %의 확률로 필터링 대상입니다.
#
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  상단  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  GNB  : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  //GNB  : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  하단  : 22.3 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#  //하단  : 22.3 %의 확률로 필터링 대상입니다.
#
#        : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  로고영역  : 19.6 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  //로고영역  : 19.6 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#     		logo_img = "https://nstatic.dcinside.com/dc/w/images/dcin_logo.png";
#     		logo_prefix = "";
#     	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	    : 22.2 %의 확률로 필터링 대상입니다.
#  갤러리 통합검색  : 34.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  //갤러리 통합검색  : 34.2 %의 확률로 필터링 대상입니다.
#
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  검색 자동완성 레이어 : 20.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  //검색 자동완성 레이어  : 20.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# 갤러리 검색 : 21.3 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# 통합검색 : 34.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 			   : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 검색 : 21.3 %의 확률로 필터링 대상입니다.
# 자동완성 레어이 : display:block  : 22.6 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
#        : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  		  		 : 22.2 %의 확률로 필터링 대상입니다.
#  	  		 : 22.2 %의 확률로 필터링 대상입니다.
#  		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 마이너갤 : 21.5 %의 확률로 필터링 대상입니다.
# 미니갤 : 21.5 %의 확률로 필터링 대상입니다.
# 갤로그 : 21.5 %의 확률로 필터링 대상입니다.
# 디시뉴스 : 19.0 %의 확률로 필터링 대상입니다.
# 디시게임 : 25.9 %의 확률로 필터링 대상입니다.
# 디시위키 : 22.2 %의 확률로 필터링 대상입니다.
# 이벤트 : 22.6 %의 확률로 필터링 대상입니다.
# 만두몰 : 22.5 %의 확률로 필터링 대상입니다.
# 로그인 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 야간모드 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 			   : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 야간 모드를 이용해 보세요 : 19.7 %의 확률로 필터링 대상입니다.
#
#        : 22.2 %의 확률로 필터링 대상입니다.
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#  어제 게시글,댓글 등록  : 39.9 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#  /어제 게시글,댓글 등록  : 39.9 %의 확률로 필터링 대상입니다.
#
#        : 22.2 %의 확률로 필터링 대상입니다.
# GNB : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#                      : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#  2차메뉴  : 52.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#  //2차메뉴  : 52.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
# 갤러리 : 22.2 %의 확률로 필터링 대상입니다.
# 2차메뉴 열림 : display:block  : 70.5 %의 확률로 필터링 대상입니다.
#
#                : 22.2 %의 확률로 필터링 대상입니다.
#
#                : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                  : 22.2 %의 확률로 필터링 대상입니다.
#
#                : 22.2 %의 확률로 필터링 대상입니다.
# 게임 : 25.9 %의 확률로 필터링 대상입니다.
# 연예/방송 : 28.0 %의 확률로 필터링 대상입니다.
# 스포츠 : 23.6 %의 확률로 필터링 대상입니다.
# 교육/금융/IT : 46.0 %의 확률로 필터링 대상입니다.
# 여행/음식/생물 : 27.0 %의 확률로 필터링 대상입니다.
# 취미/생활 : 24.9 %의 확률로 필터링 대상입니다.
# 마이너갤 : 21.5 %의 확률로 필터링 대상입니다.
# 미니갤 : 21.5 %의 확률로 필터링 대상입니다.
# 갤로그 : 21.5 %의 확률로 필터링 대상입니다.
# 디시뉴스 : 19.0 %의 확률로 필터링 대상입니다.
# 디시게임 : 25.9 %의 확률로 필터링 대상입니다.
# 디시위키 : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#
#          : 22.2 %의 확률로 필터링 대상입니다.
#  2차메뉴 열림 클래스 open /  닫힘시 open 삭제   : 91.5 %의 확률로 필터링 대상입니다.
#
#             더보기
#            : 71.4 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#                : 22.2 %의 확률로 필터링 대상입니다.
#
#                : 22.2 %의 확률로 필터링 대상입니다.
#
#              : 22.2 %의 확률로 필터링 대상입니다.
# 이벤트 : 22.6 %의 확률로 필터링 대상입니다.
# 만두몰 : 22.5 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#            : 22.2 %의 확률로 필터링 대상입니다.
#
#          : 22.2 %의 확률로 필터링 대상입니다.
# 어제  : 43.8 %의 확률로 필터링 대상입니다.
#  게시글 등록 : 24.4 %의 확률로 필터링 대상입니다.
# 903,303개 : 31.9 %의 확률로 필터링 대상입니다.
# 어제  : 43.8 %의 확률로 필터링 대상입니다.
#  댓글 등록 : 19.6 %의 확률로 필터링 대상입니다.
# 2,337,716개 : 31.9 %의 확률로 필터링 대상입니다.
#
#
#      : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  본문 좌측 날개 광고 배너  : 22.6 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //본문 좌측 날개 광고 배너  : 22.6 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  TOAST 배너  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //TOAST 배너  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# 일반 : 21.8 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# ADX dcinside_300_250 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# //ADX dcinside_300_250_1 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  갤리명 타이틀바 ~ 이용안내  : 15.9 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#  본문  : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#  //본문  : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#  하단 갤러리 리스트  : 22.0 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#  //하단 갤러리 리스트  : 22.0 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# 리그 오브 레전드 갤러리 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	 : 22.2 %의 확률로 필터링 대상입니다.
# 연관 갤러리(6/22)  : 23.1 %의 확률로 필터링 대상입니다.
# NEW : 22.2 %의 확률로 필터링 대상입니다.
# 연관 갤러리 열기 : 23.1 %의 확률로 필터링 대상입니다.
# 갤주소 복사 : 20.2 %의 확률로 필터링 대상입니다.
# 차단설정 : 37.6 %의 확률로 필터링 대상입니다.
# 갤러리 이용안내 : 32.6 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 더보기 : 71.4 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  갤러리 이슈박스, 최근방문 갤러리 : 23.3 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  연관갤러리  : 23.1 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  //연관갤러리  : 23.1 %의 확률로 필터링 대상입니다.
#
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  상단 이슈 박스  : 23.0 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  list and view recom  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  차단 설정  : 37.6 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  차단 간편 설정 (본문 내)  : 56.9 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //차단 설정  : 37.6 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#  최근방문 갤러리  : 20.6 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#  현갤러리 -> 타 갤러리  : 21.0 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#  //현갤러리 -> 타 갤러리  : 21.0 %의 확률로 필터링 대상입니다.
#
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#  //타 갤러리 -> 현갤러리  : 21.0 %의 확률로 필터링 대상입니다.
#
# 	  	 : 22.2 %의 확률로 필터링 대상입니다.
# 연관 갤러리 : 23.1 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	  	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
# 리그 오브 레전드 갤러리  : 22.2 %의 확률로 필터링 대상입니다.
#   타 갤러리( : 21.0 %의 확률로 필터링 대상입니다.
# ) : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 이 갤러리가 연관 갤러리로 추가한 갤러리 : 30.1 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
# 타 갤러리  : 21.0 %의 확률로 필터링 대상입니다.
#  리그 오브 레전드 갤러리( : 22.2 %의 확률로 필터링 대상입니다.
# ) : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 이 갤러리를 연관 갤러리로 추가한 갤러리 : 30.1 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
#
# 	  	  	 : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	     : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 0 : 22.2 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
# 연관 갤러리 레이어 닫기 : 56.3 %의 확률로 필터링 대상입니다.
#
# 	  <li>
# 		<a class="{{if typeof(is_new) != 'undefined' && is_new == 'A_NEW'}}newtxt{{/if}}{{if state == 'N'}} restriction{{/if}}" href="{{if gall_type == 'MI'}}/mini{{/if}}/board/lists?id=${name}">
# 		  ${ko_name}{{if gall_type == 'M'}}{{/if}}{{if gall_type == 'MI'}}<em class="icon_mini">ⓝ</em>{{/if}}{{if state == 'N'}}<span><em class="blind">접근제한</em><em class="sp_img icon_restriction"></em></span>{{/if}}
# 		</a>
# 	  </li>
# 	   : 19.6 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# 개념글 리스트 : 41.4 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 1 : 22.2 %의 확률로 필터링 대상입니다.
# 3 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
#
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 결승 이거 볼생각에 가슴이 웅장해지면 개추 : 15.1 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 김민아 <<< LCK 진행자 복귀 원하면 개추 : 17.3 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 페이커가 우승한 물로켓대회 규모는 어느정도 였을까?.jpg : 90.8 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 미드 4대천왕 스탯...JPG : 22.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# ??? : 결국에 남는건 커리어라고? : 23.3 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 역대급 데뷔전 비교 고전파 VS 미키갓 : 24.1 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 진지하게 젠지가 우승할거같으면 개추 ㅋㅋㅋㅋㅋㅋㅋㅋ : 24.9 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 결승전 념글예상.jpg : 22.8 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 고전파 역대급 신격화 거품이라 생각되면 개추 ㅋㅋㅋㅋㅋ : 14.1 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# ■ T1 발로란트 팀 승부조작, 부정행위자들 영입 : 90.6 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# ■지능+100 페이커 플레이.gif : 22.1 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 젠지가 이기면 좋겠다 개추 ㅋㅋㅋㅋㅋ : 27.3 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 젠지 우승각보인다 그냥 젠지가 더잘한다 : 96.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# ■실시간..즙마갤 발작버튼 ON ㅋㅋ...JPG : 21.3 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 결승당일 아침 첫 념글...JPG : 21.4 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 공감)LCK 호감 미드라이너 3대장.JPG : 68.1 %의 확률로 필터링 대상입니다.
# ㄹㅇ 인성 좋고 실력으로 증명도해서 ㅈㄴ 호감임 : 99.7 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#  : ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# 작성자 : 22.2 %의 확률로 필터링 대상입니다.
# 고정닉 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 나는 슼갈이고 페이커가 빈집이 아닌 정정당당한 역체롤이라고 생각되면 비추 : 16.4 %의 확률로 필터링 대상입니다.
# 슼갈 개많노 ㅋㅋㅋㅋㅋㅋㅋ : 87.3 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#  : ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# 작성자 : 22.2 %의 확률로 필터링 대상입니다.
# 고정닉 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
# 결승 관람 전... 방 안 빼는 물로켓단 판별법...fact : 31.4 %의 확률로 필터링 대상입니다.
# 들어가기에 앞서팩트 1: 정상적인 롤팬은 타 팀을 협잡질하거나 가면질하지 않는다.(협잡, 가면 = 전형적인 아이돌식 팬 문화)팩트 2: 담원 젠지, 모두 최선을 다 할 것이며, 명경기를 선보일 것이다.팩트 3: "물로켓 찌익~"은 물로켓단을 제외하고 누구에게도 피해를 주지 않는 단어다.팩트 4: 물로켓단은 물로켓론을 지금까지 반박은 커녕 : 98.7 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#  : ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# 작성자 : 22.2 %의 확률로 필터링 대상입니다.
# 고정닉 : 22.2 %의 확률로 필터링 대상입니다.
#
# topbox_recomAjax();
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
# 차단하기 : 22.8 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
# 차단설정을 통해 게시물을 걸러서 볼 수 있습니다. : 42.5 %의 확률로 필터링 대상입니다.
# [리그 오브 레전드 갤러리] : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 		  		   : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
# 차단 닉네임 : 23.2 %의 확률로 필터링 대상입니다.
# 등록 : 23.4 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		   : 22.2 %의 확률로 필터링 대상입니다.
# 차단 IP : 23.2 %의 확률로 필터링 대상입니다.
# 등록 : 23.4 %의 확률로 필터링 대상입니다.
# 차단설정 레이어 닫기 : 77.1 %의 확률로 필터링 대상입니다.
#
# 	  	   : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  210310 최근방문 레이어  : 20.6 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  //210310 최근방문 레이어  : 20.6 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# 최근 방문 : 20.6 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
# 리그 오브 레전드 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 모여봐요 동물의 숲 : 16.6 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 초개념 : 23.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 디모 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 쓰르라미 울적에 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 중세게임 : 34.0 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 메이플스토리 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 일본 연예 : 70.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 경비.보안 : 23.3 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 디지털 사진 : 17.0 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 건담  : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 초개념 : 23.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 자전거 : 41.6 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 방도리 성우 : 22.9 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# PKL : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
#
# 	<li class = "visit_${id}"><a href="//${link}" data-link="//${link}" class="logClass{{if type == 'MI'}} mini{{/if}}" depth1="topframe" depth2="gall_lately" depth3="${id}">${name}</a>{{if type == 'MI'}}<em class="icon_mini">미니갤러리</em>{{/if}}<button type="button" class="btn_visit_del" data-id="${id}" data-gtype="${type}"><span class="blind">삭제</span><em class="icon_visit_del"></em></button></li>
# 	 : 20.2 %의 확률로 필터링 대상입니다.
# 최근 방문 갤러리가 없습니다. : 22.4 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
# 전체 : 25.8 %의 확률로 필터링 대상입니다.
# 210310  미니갤러리의 경우 클래스 lightpurple 삽입 : 20.5 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 최근 방문 갤러리는 50개까지 기록됩니다. : 21.4 %의 확률로 필터링 대상입니다.
# 전체 삭제 : 24.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				<li class = "visit_${id}"><a href="//${link}" class="logClass{{if type == 'MI'}} mini{{/if}}" depth1="topframe" depth2="gall_lately" depth3="${id}">${name}</a>{{if type == 'MI'}}<em class="icon_mini">미니갤러리</em>{{/if}}<button type="button" class="btn_visit_del" data-id="${id}" data-gtype="${type}"><span class="blind">삭제</span><em class="icon_visit_del"></em></button></li>
# 				 : 20.2 %의 확률로 필터링 대상입니다.
# 리그 오브 레전드 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 모여봐요 동물의 숲 : 16.6 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 초개념 : 23.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 디모 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 쓰르라미 울적에 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 중세게임 : 34.0 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 메이플스토리 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 일본 연예 : 70.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 경비.보안 : 23.3 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 디지털 사진 : 17.0 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 건담  : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 초개념 : 23.4 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 자전거 : 41.6 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 방도리 성우 : 22.9 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# PKL : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 최근 방문 갤러리가 없습니다. : 22.4 %의 확률로 필터링 대상입니다.
# 갤러리 전체보기 레이어 닫기 : 90.2 %의 확률로 필터링 대상입니다.
#
# lately_gall_init('leagueoflegends4', '리그 오브 레전드', 'G');
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#  댓글  : 20.0 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  개념글, 수정, 삭제, 글쓰기 버튼 영역 : 31.7 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#  //개념글, 수정, 삭제, 글쓰기 버튼 영역 : 31.7 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 갤러리 본문 영역 : 21.5 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#  모바일에서 작성 icon_write_mbl  : 22.8 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 속보)고버지 좆됐다; .real : 96.6 %의 확률로 필터링 대상입니다.
# 앱에서 작성 : 35.8 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
# 																 : 22.2 %의 확률로 필터링 대상입니다.
#
# 															 : 22.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (118.235) : 22.2 %의 확률로 필터링 대상입니다.
# 2021.03.16 22:36:52 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 조회 57192 : 22.2 %의 확률로 필터링 대상입니다.
# 추천 625 : 21.2 %의 확률로 필터링 대상입니다.
# 댓글 149 : 20.0 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  추천검색 : 19.7 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //추천검색 : 19.7 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //추천캡차 : 21.2 %의 확률로 필터링 대상입니다.
#
# 						                					 : 22.2 %의 확률로 필터링 대상입니다.
#  추천 비추천  : 19.1 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //추천 비추천  : 19.1 %의 확률로 필터링 대상입니다.
#
# 										 : 22.2 %의 확률로 필터링 대상입니다.
#  본문 하단 광고  : 23.1 %의 확률로 필터링 대상입니다.
#
# 										 : 22.2 %의 확률로 필터링 대상입니다.
#
#                                          : 22.2 %의 확률로 필터링 대상입니다.
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //본문 하단 광고  : 23.1 %의 확률로 필터링 대상입니다.
#
# 										 : 22.2 %의 확률로 필터링 대상입니다.
#  원본 첨부 파일  : 21.5 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //원본 첨부 파일  : 21.5 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#   본문 우측 광고  : 22.6 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#   //본문 우측 광고  : 22.6 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 								 : 22.2 %의 확률로 필터링 대상입니다.
# 위대한 도둑 : 40.6 %의 확률로 필터링 대상입니다.
# 라이프의 : 22.2 %의 확률로 필터링 대상입니다.
# 서폿 다리우스 입갤 ㄷㄷ : 16.2 %의 확률로 필터링 대상입니다.
#    : 22.2 %의 확률로 필터링 대상입니다.
# " : 22.2 %의 확률로 필터링 대상입니다.
# 처형" 확정 : 19.3 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 추천검색 : 19.7 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 												 : 22.2 %의 확률로 필터링 대상입니다.
#
# 												 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 추천 비추천 : 19.1 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 625 : 22.2 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
#                 						 : 22.2 %의 확률로 필터링 대상입니다.
#
#             						 : 22.2 %의 확률로 필터링 대상입니다.
# 101 : 22.2 %의 확률로 필터링 대상입니다.
# 개념 추천 : 38.7 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 개념 비추천 : 44.1 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 23 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 힛추 : 22.2 %의 확률로 필터링 대상입니다.
# 공유 : 21.6 %의 확률로 필터링 대상입니다.
# 신고 : 21.2 %의 확률로 필터링 대상입니다.
#
#                                           window._taboola = window._taboola || [];
#                                           _taboola.push({
#                                             mode: 'thumbnails-d',
#                                             container: 'taboola-below-article-thumbnails',
#                                             placement: 'Below Article Thumbnails',
#                                             target_type: 'mix'
#                                           });
#                                          : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 원본 첨부파일  : 22.2 %의 확률로 필터링 대상입니다.
# 2 : 22.2 %의 확률로 필터링 대상입니다.
# 본문 이미지 다운로드 : 22.9 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# edit_1615901617201.jpg : 22.2 %의 확률로 필터링 대상입니다.
# edit_1615901627467.jpg : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#  답글 입력  : 42.0 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  답글쓰기  : 21.9 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //수정  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  앨범형 댓글쓰기  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#  //앨범형 댓글쓰기  : 22.2 %의 확률로 필터링 대상입니다.
#
#  : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
#  : 22.2 %의 확률로 필터링 대상입니다.
# 댓글 영역 : 18.8 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				전체 댓글  : 23.8 %의 확률로 필터링 대상입니다.
# 개
# 				 : 31.9 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 149 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 등록순 : 23.0 %의 확률로 필터링 대상입니다.
# 최신순 : 19.8 %의 확률로 필터링 대상입니다.
# 답글수 : 22.2 %의 확률로 필터링 대상입니다.
# 등록순 : 23.0 %의 확률로 필터링 대상입니다.
# 정렬 기준선택 : 36.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# <li class="comment_sort" data-sort="I">등록순</li> : 23.0 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 등록순 : 23.0 %의 확률로 필터링 대상입니다.
# 최신순 : 19.8 %의 확률로 필터링 대상입니다.
# 답글순 : 22.2 %의 확률로 필터링 대상입니다.
# 답글 펼침 설정 : 51.5 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
# 본문 보기 : 58.6 %의 확률로 필터링 대상입니다.
# 댓글닫기 : 21.9 %의 확률로 필터링 대상입니다.
# 새로고침 : 22.2 %의 확률로 필터링 대상입니다.
# 팡교관교 : 23.2 %의 확률로 필터링 대상입니다.
# 근데 이긴거? ㅋㅋㅋㅋㅋㅋ : 26.3 %의 확률로 필터링 대상입니다.
# 03.16 23:08:21 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 팔붕아 : 22.2 %의 확률로 필터링 대상입니다.
# 개지랄났노시발ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:08:42 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (58.125) : 22.2 %의 확률로 필터링 대상입니다.
# 레오나 알리 렐같이 들어와서 몸비비는 애들 카운터치기는 충분 한거같은데  - dc App : 76.0 %의 확률로 필터링 대상입니다.
# 03.16 23:09:35 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (39.7) : 22.2 %의 확률로 필터링 대상입니다.
# 룰러도 세나 괜찮던데 나올수 있을듯 : 58.8 %의 확률로 필터링 대상입니다.
# 03.16 23:09:57 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (222.119) : 22.2 %의 확률로 필터링 대상입니다.
# 펜타킬했잖아 : 21.4 %의 확률로 필터링 대상입니다.
# 03.16 23:10:29 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.253) : 22.2 %의 확률로 필터링 대상입니다.
# 그거 폭식아님? : 47.2 %의 확률로 필터링 대상입니다.
# 03.16 23:13:42 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (180.66) : 22.2 %의 확률로 필터링 대상입니다.
# 룰러는 단식 세나 같이 완전 받쳐주는 픽 안좋아할텐데 할려나 : 23.2 %의 확률로 필터링 대상입니다.
# 03.16 23:36:40 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (175.223) : 22.2 %의 확률로 필터링 대상입니다.
# 비원딜안해 포바안해 케틀안해 사미라안해 징크스안해 트타안해 세나안해 시팔 안하는거맞냐? : 98.6 %의 확률로 필터링 대상입니다.
# 응디디 라이프만 ㅈㄹ할게 아님  : 87.8 %의 확률로 필터링 대상입니다.
# 룰러 이새끼도 존나 안하는거많음 : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:42:10 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (1.242) : 22.2 %의 확률로 필터링 대상입니다.
# 트타는 향로메타때 존나게했다. 3연트타로 롱주떡냈구만. 징크스는 서폿이쓰레쉬를안하는데 어케씀 : 99.9 %의 확률로 필터링 대상입니다.
# 03.17 01:18:13 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (118.217) : 22.2 %의 확률로 필터링 대상입니다.
# 룰러 이새끼는 메타챔 못쓰다가 나중가다 잘씀 : 100.0 %의 확률로 필터링 대상입니다.
# 03.17 02:15:19 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (223.39) : 22.2 %의 확률로 필터링 대상입니다.
# 룰러 그래도 야스오도 했다 : 32.9 %의 확률로 필터링 대상입니다.
# 03.17 02:59:18 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.253) : 22.2 %의 확률로 필터링 대상입니다.
# 쓰레쉬없이 아펠은 쓰면서 징크스는 왜안쓸까 ㅋㅋ 사실 쓰레쉬 없으면 둘 다 안쓰는게 맞긴한데 : 10.4 %의 확률로 필터링 대상입니다.
# 03.17 06:37:57 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.33) : 22.2 %의 확률로 필터링 대상입니다.
# 룰러 예전에 징크스 꽤 쓴 적 있던거 같은데 요새 쓰레쉬 없이는 징크스 뽑으면 안되서 안쓰는거 아니냐 : 23.8 %의 확률로 필터링 대상입니다.
# 03.17 10:04:22 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (106.101) : 22.2 %의 확률로 필터링 대상입니다.
# 175.223 비원딜빼고는 솔랭에서는 다 함 저런 픽들 팀차원에서 안하기로 결정된거라고 봐야함  - dc App : 77.1 %의 확률로 필터링 대상입니다.
# 03.17 11:34:35 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.107) : 22.2 %의 확률로 필터링 대상입니다.
# 아펠도 억지로 함 ㅋㅋ 그래서 룰러 아펠성적 좋지가않음 진짜 쓰레쉬못하는건 레전드다 : 95.2 %의 확률로 필터링 대상입니다.
# 03.17 11:36:50 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (116.123) : 22.2 %의 확률로 필터링 대상입니다.
# 아펠요번시즌성적좋던데? 솔랭말하는건가? : 17.4 %의 확률로 필터링 대상입니다.
# 03.17 13:07:13 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (175.223) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 상식적으로 팀에이스한테 맞춰주는게 맞는거 아님? 아무리 라이프 쓰레쉬 못한다고 지랄나도 결국 룰러가 OK하니까 넘어가는거 아님? : 100.0 %의 확률로 필터링 대상입니다.
# 03.17 21:17:15 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (39.124) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 아펠이랑 징크스는 쓰레쉬 없으면 절대 쓰면 안 됨 : 14.7 %의 확률로 필터링 대상입니다.
# 03.18 14:51:04 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 댓글돌이 : 20.5 %의 확률로 필터링 대상입니다.
# 39년 못깨어난 흑인 축구영웅, 그옆 지킨 한 여자의 순애보 : 41.5 %의 확률로 필터링 대상입니다.
#
#     	            							 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                            		 : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
# 1 : 22.2 %의 확률로 필터링 대상입니다.
# 10 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (112.173) : 22.2 %의 확률로 필터링 대상입니다.
# 바텀 찟겼네 ㅋㅋ : 21.4 %의 확률로 필터링 대상입니다.
# 03.16 23:10:01 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (110.70) : 22.2 %의 확률로 필터링 대상입니다.
# 찐)비원딜 다리우스에 세나 서폿이다 : 54.3 %의 확률로 필터링 대상입니다.
# 03.16 23:10:17 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (59.24) : 22.2 %의 확률로 필터링 대상입니다.
# 진짜 나올수도 ㅋㅋ : 20.5 %의 확률로 필터링 대상입니다.
# 03.16 23:10:28 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (124.50) : 22.2 %의 확률로 필터링 대상입니다.
# https://www.youtube.com/watch?v=Rl_704_Ih3g : 22.2 %의 확률로 필터링 대상입니다.
# 03.16 23:10:42 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (59.24) : 22.2 %의 확률로 필터링 대상입니다.
# 비디디는 솔랭에서도 좆지르하네 : 98.0 %의 확률로 필터링 대상입니다.
# 03.16 23:11:03 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.177) : 22.2 %의 확률로 필터링 대상입니다.
# 진짜 연봉도둑맞노ㅋㅋㅋㅋ  - dc App : 96.6 %의 확률로 필터링 대상입니다.
# 03.16 23:12:04 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (222.119) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 세나하고 조합이면 ㅈㄴ특이한거도 많이나올수있어서 쓸만할수도 있는데 젠지는 세나안할듯 : 94.5 %의 확률로 필터링 대상입니다.
# 03.16 23:12:14 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (27.115) : 22.2 %의 확률로 필터링 대상입니다.
# 세나 다리우스 오히려 베릴이 저거 보고 해보는거 아니냐 룰러가 단식세나 하냐 : 37.8 %의 확률로 필터링 대상입니다.
# 03.16 23:15:35 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (223.38) : 22.2 %의 확률로 필터링 대상입니다.
# 베릴때문에 좆된거노? : 97.3 %의 확률로 필터링 대상입니다.
# 03.16 23:19:36 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (175.214) : 22.2 %의 확률로 필터링 대상입니다.
# 코릴 '다리우스' 못막는다 : 21.3 %의 확률로 필터링 대상입니다.
# 03.17 01:31:41 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 댓글돌이 : 20.5 %의 확률로 필터링 대상입니다.
# 英 필립공 장례식은 왕실장으로…버킹엄궁 앞엔 추모 행렬
#  : 16.5 %의 확률로 필터링 대상입니다.
#
#     	            							 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                            		 : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
# 1 : 22.2 %의 확률로 필터링 대상입니다.
# 10 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.36) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 바텀이 캐리했네ㅋㅋㅋㅋ : 43.1 %의 확률로 필터링 대상입니다.
# 03.16 23:16:03 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (59.14) : 22.2 %의 확률로 필터링 대상입니다.
# 생각해보면 렐 상대로 ㄹㅇ 괜찮을수도 있겠네 들어오면 죽이니까 : 83.4 %의 확률로 필터링 대상입니다.
# 03.16 23:16:11 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.214) : 22.2 %의 확률로 필터링 대상입니다.
# 비디디는 솔랭에서도 아지르하네 ㅋㅋㅋㅋ : 87.1 %의 확률로 필터링 대상입니다.
# 03.16 23:16:17 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (180.66) : 22.2 %의 확률로 필터링 대상입니다.
# 응디디 솔랭 전적 보니깐 이렐이 모스트고 아지르 몇판 없던데? : 97.6 %의 확률로 필터링 대상입니다.
# 03.16 23:38:53 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (182.211) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 왜 잘했노 시발ㅋㅋㅋㅋ : 99.9 %의 확률로 필터링 대상입니다.
# 03.16 23:18:27 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.36) : 22.2 %의 확률로 필터링 대상입니다.
# ㄹㅇㅋㅋㅋ : 22.2 %의 확률로 필터링 대상입니다.
# 03.16 23:18:46 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 카이만 : 22.2 %의 확률로 필터링 대상입니다.
# 시발ㅋㅋㅋㅋㅋ - dc App : 99.9 %의 확률로 필터링 대상입니다.
# 03.16 23:18:55 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.184) : 22.2 %의 확률로 필터링 대상입니다.
# 비디디 아지르 눈썩토스 하고나서도 아지르가 손에 잡히나 프로가 다르긴 다르네 ㅋㅋ : 96.2 %의 확률로 필터링 대상입니다.
# 03.16 23:20:40 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (175.213) : 22.2 %의 확률로 필터링 대상입니다.
# 실수 한번 했다고 손에 안잡히면 즙은 18년도에 은퇴했겠노 ㅋㅋ : 14.5 %의 확률로 필터링 대상입니다.
# 03.16 23:23:47 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (110.70) : 22.2 %의 확률로 필터링 대상입니다.
# 즙 0인 공기팡은 어케참았노? : 44.3 %의 확률로 필터링 대상입니다.
# 03.16 23:25:21 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (49.163) : 22.2 %의 확률로 필터링 대상입니다.
# 실수한번 했다고 안잡히면 세상에 아지르 하는놈이 어딨노 : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:31:51 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (61.101) : 22.2 %의 확률로 필터링 대상입니다.
# 팩트) 느그즙은 아지르 궁 하나로 이블린 트위치 샤코 탈론 카직스 베인 6인궁을 맞춘적이 있다 : 94.7 %의 확률로 필터링 대상입니다.
# 03.16 23:33:18 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.184) : 22.2 %의 확률로 필터링 대상입니다.
# 바로 갈드컵 열어버리네 씨발년들 뭔 말을 못하겠어 : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:34:34 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (39.7) : 22.2 %의 확률로 필터링 대상입니다.
# 뭔말을 못하겠어 ㅇㅈㄹㅋㅋㅋㅋ 피냄새 역하노 : 15.0 %의 확률로 필터링 대상입니다.
# 03.16 23:41:39 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (58.232) : 22.2 %의 확률로 필터링 대상입니다.
# 무관견들 즈그주인 응디디한테 쳐발리니까 견제들어가네 ㅋㅋ : 99.1 %의 확률로 필터링 대상입니다.
# 03.16 23:48:00 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 선형근사 : 22.2 %의 확률로 필터링 대상입니다.
# 갈드컵 거르고 안잡힌다며 방치하면 챔이 남는 미드라이너가 어딨겠노 ㅋㅋㅋㅋ : 34.7 %의 확률로 필터링 대상입니다.
# 03.17 00:14:00 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (211.58) : 22.2 %의 확률로 필터링 대상입니다.
# 벤치견들은 솔카한테 쳐발리고 말이 많노.. : 60.9 %의 확률로 필터링 대상입니다.
# 03.17 01:00:59 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (220.79) : 22.2 %의 확률로 필터링 대상입니다.
# 진짜 무슨말만하면 슥갈로 만들어버리네 씨발 ㅋㅋㅋㅋ : 100.0 %의 확률로 필터링 대상입니다.
# 03.17 01:19:21 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (59.11) : 22.2 %의 확률로 필터링 대상입니다.
# 이쯤되면 페이커 학폭 조사 ㄹㅇ 한번 해봐야되는거 아님? 학창시절에 개쳐맞은게 아니고서야 이럴 수가 없을 것 같은데 : 93.0 %의 확률로 필터링 대상입니다.
# 03.17 08:28:31 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (110.70) : 22.2 %의 확률로 필터링 대상입니다.
# 누가보면 즙까는댓글이 먼저인줄 알겠노 ㅋㅋ 즙갈들 피해망상은 못말려 : 86.1 %의 확률로 필터링 대상입니다.
# 03.17 17:01:04 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 댓글돌이 : 20.5 %의 확률로 필터링 대상입니다.
# 심야 영화 관람 중 라이터에 불 켜고 소동…징역 6개월
#  : 14.0 %의 확률로 필터링 대상입니다.
#
#     	            							 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                            		 : 22.2 %의 확률로 필터링 대상입니다.
# / : 22.2 %의 확률로 필터링 대상입니다.
# 1 : 22.2 %의 확률로 필터링 대상입니다.
# 10 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	            								 : 22.2 %의 확률로 필터링 대상입니다.
#
#     	                              			 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (222.117) : 22.2 %의 확률로 필터링 대상입니다.
# 쓰레쉬나 하라고 제발ㅋㅋ : 18.0 %의 확률로 필터링 대상입니다.
# 03.16 23:21:24 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (124.197) : 22.2 %의 확률로 필터링 대상입니다.
# 다리우스 단점이 갱에 취약하고 라인전 한 번이라도 말리면 좆병신 되는 건데 단식세나가 커버 쳐줄 수 있을 거 같은데 : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:21:33 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (125.182) : 22.2 %의 확률로 필터링 대상입니다.
# 트타 렐이면 둘 다 쩜프하는순간 뒤지겠는데 ㅋㅋㅋ : 93.7 %의 확률로 필터링 대상입니다.
# 03.16 23:23:58 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (121.186) : 22.2 %의 확률로 필터링 대상입니다.
# 세나 다리우스 기대된다! : 19.0 %의 확률로 필터링 대상입니다.
# 03.16 23:24:13 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# 마빈게이 : 36.9 %의 확률로 필터링 대상입니다.
# 위대한 도둑 이지랄 ㅋㅋㅋㅋㅋㅋ : 99.9 %의 확률로 필터링 대상입니다.
# 03.16 23:24:42 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (218.55) : 22.2 %의 확률로 필터링 대상입니다.
# 이게 뭔 ㅋㅋㅋㅋ : 27.9 %의 확률로 필터링 대상입니다.
# 03.16 23:26:15 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# 룰러가 단식세나를 해야한다 : 44.6 %의 확률로 필터링 대상입니다.
# 03.16 23:27:09 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (27.115) : 22.2 %의 확률로 필터링 대상입니다.
# 말은 절대 안듣노 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 16.9 %의 확률로 필터링 대상입니다.
# 03.16 23:27:23 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (118.235) : 22.2 %의 확률로 필터링 대상입니다.
# 클리드는 당하면서 뭔생각 했을까 ㅋㅋ : 80.0 %의 확률로 필터링 대상입니다.
# 03.16 23:28:34 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# 근데 렐이라서 진심 ㄱㅊ을꺼같은데 w e로 끊어지고 이속 느려서 5스택 쉽고 : 61.6 %의 확률로 필터링 대상입니다.
# 03.16 23:28:48 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (175.115) : 22.2 %의 확률로 필터링 대상입니다.
# 주류챔프폭 늘리라니까 시발 다리우스를 늘리고 있노 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ : 100.0 %의 확률로 필터링 대상입니다.
# 03.16 23:29:25 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ㅇㅇ : 29.4 %의 확률로 필터링 대상입니다.
# (125.141) : 22.2 %의 확률로 필터링 대상입니다.
# 근데 룰러가 단식세나를 할지가 문제 아니노 ㅋㅋㅋㅋ : 78.6 %의 확률로 필터링 대상입니다.
# 03.16 23:32:54 : 22.2 %의 확률로 필터링 대상입니다.
# 삭제 : 20.2 %의 확률로 필터링 대상입니다.
# ...
# 한화 이글스 : 22.2 %의 확률로 필터링 대상입니다.
# 삼성 라이온즈 : 32.1 %의 확률로 필터링 대상입니다.
# 키움 히어로즈 : 21.2 %의 확률로 필터링 대상입니다.
# 해외축구 : 19.0 %의 확률로 필터링 대상입니다.
# 교육/금융/IT : 46.0 %의 확률로 필터링 대상입니다.
# 비트코인 : 22.2 %의 확률로 필터링 대상입니다.
# 부동산 : 21.9 %의 확률로 필터링 대상입니다.
# 정치, 사회 : 19.5 %의 확률로 필터링 대상입니다.
# 컴퓨터 본체 : 23.2 %의 확률로 필터링 대상입니다.
# 이어폰, 헤드폰 : 22.2 %의 확률로 필터링 대상입니다.
# 공무원 : 20.6 %의 확률로 필터링 대상입니다.
# 행정 : 20.9 %의 확률로 필터링 대상입니다.
# 자격증 : 21.3 %의 확률로 필터링 대상입니다.
# 주식 : 22.5 %의 확률로 필터링 대상입니다.
# 성형 : 25.1 %의 확률로 필터링 대상입니다.
# 여행/음식/생물 : 27.0 %의 확률로 필터링 대상입니다.
# 여행-동남아 : 25.9 %의 확률로 필터링 대상입니다.
# 도시 : 22.9 %의 확률로 필터링 대상입니다.
# 편의점 : 23.4 %의 확률로 필터링 대상입니다.
# 주류 : 26.0 %의 확률로 필터링 대상입니다.
# 치킨 : 22.2 %의 확률로 필터링 대상입니다.
# 기타음식 : 19.9 %의 확률로 필터링 대상입니다.
# 야옹이 : 22.2 %의 확률로 필터링 대상입니다.
# 식물 : 22.4 %의 확률로 필터링 대상입니다.
# 멍멍이 : 38.6 %의 확률로 필터링 대상입니다.
# 동물,기타 : 21.3 %의 확률로 필터링 대상입니다.
# 취미/생활 : 24.9 %의 확률로 필터링 대상입니다.
# 인터넷방송 : 20.1 %의 확률로 필터링 대상입니다.
# 판타지 : 23.6 %의 확률로 필터링 대상입니다.
# 토이 : 22.2 %의 확률로 필터링 대상입니다.
# 역학 : 22.2 %의 확률로 필터링 대상입니다.
# 대출 : 20.9 %의 확률로 필터링 대상입니다.
# 미스터리 : 22.2 %의 확률로 필터링 대상입니다.
# 만화 : 23.7 %의 확률로 필터링 대상입니다.
# 카툰-연재 : 22.2 %의 확률로 필터링 대상입니다.
# 상의 : 22.2 %의 확률로 필터링 대상입니다.
# 신발 : 35.5 %의 확률로 필터링 대상입니다.
#
# 	    : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	    : 22.2 %의 확률로 필터링 대상입니다.
# 맨위로 : 19.7 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#         : 22.2 %의 확률로 필터링 대상입니다.
#
#
#
#       : 22.2 %의 확률로 필터링 대상입니다.
# 회사소개 : 40.1 %의 확률로 필터링 대상입니다.
# 인재채용 : 21.0 %의 확률로 필터링 대상입니다.
# 제휴안내 : 32.2 %의 확률로 필터링 대상입니다.
# 광고안내 : 33.6 %의 확률로 필터링 대상입니다.
# 이용약관 : 22.6 %의 확률로 필터링 대상입니다.
# 개인정보처리방침 : 27.8 %의 확률로 필터링 대상입니다.
# 청소년보호정책 : 32.2 %의 확률로 필터링 대상입니다.
# Copyright ⓒ 1999 - 2021 dcinside. All rights reserved. : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#   : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#  dccon_list_wrap  : 22.2 %의 확률로 필터링 대상입니다.
#
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	 	  : 22.2 %의 확률로 필터링 대상입니다.
#  //dccon_list_wrap  : 22.2 %의 확률로 필터링 대상입니다.
#
# 	  : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 리스트 : 21.9 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  디시콘 목록  : 21.7 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  //디시콘 목록  : 21.7 %의 확률로 필터링 대상입니다.
#
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  디시콘 리스트 dccon_list_box  : 21.9 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  //디시콘 리스트 dccon_list_box  : 21.9 %의 확률로 필터링 대상입니다.
#
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  인기 디시콘  : 21.4 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  //인기 디시콘  : 21.4 %의 확률로 필터링 대상입니다.
#
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  디시콘 보관함 사용 / 미사용 리스트 : 92.7 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#  //디시콘 보관함 사용 / 미사용 리스트 : 92.7 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  tab_btnlist  : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#  //tab_btnlist  : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					  : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 최근사용 디시콘 : 19.7 %의 확률로 필터링 대상입니다.
#
# 				<li class = "li_pack">
# 					<button type="button" class="dccon_btn no_btn" package_idx = "${package_idx}" title= "${title}">
# 					<img src="${main_img_url}" alt="${title}">
# 					</button>
# 					<span class="frame"></span>
# 				</li>
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 인기 디시콘 : 21.4 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 관리 : 21.6 %의 확률로 필터링 대상입니다.
#
# 		<ul class="dccon_list clear page_${page}_index_${index}" >
# 			{{each detail}}
# 			{{if ($index < list_page) }}
# 			<li class = "list_${parseInt($index / list_page) + 1} list_li" >
# 			{{else}}
# 			<li class = "list_${parseInt($index / list_page) + 1} list_li" style = "display:none;">
# 			{{/if}}
# 			<button type="button" class="img_dccon" detail_idx="${detail_idx}" package_idx="${package_idx}" title="${title}"><img src="${list_img}" alt="${title}"></button></li>
# 			{{/each}}
# 			<li>
# 				<div class="btn_box dccon_list_paging">
# 				<button type="button" class="btn_prev ${btn_prev_on}"><span class="blind">이전</span><em class="sp_img icon_prev"></em></button>
# 				<div class="page_num">
# 					<strong class="now_num">1</strong>/<span class="total_num">${detail_page}</span>
# 				</div>
# 				<button type="button" class="btn_next ${btn_next_on}"><span class="blind">다음</span><em class="sp_img icon_next"></em></button>
# 				</div>
# 			</li>
# 		</ul>
# 		 : 19.9 %의 확률로 필터링 대상입니다.
#
# 		<li><button type="button" class="img_dccon" detail_idx="${idx}" package_idx="${package_idx}" title="${title}"><img src="${list_img}" alt="${title}"></button></li>
# 		 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			   : 22.2 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 			   : 22.2 %의 확률로 필터링 대상입니다.
#
# 				   : 22.2 %의 확률로 필터링 대상입니다.
#
# 				   : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				   : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 검색결과 : 19.0 %의 확률로 필터링 대상입니다.
# (0) : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						   : 22.2 %의 확률로 필터링 대상입니다.
#
# 						   : 22.2 %의 확률로 필터링 대상입니다.
#
# 						   : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						   : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘명 : 22.2 %의 확률로 필터링 대상입니다.
# 정렬 기준선택 : 36.2 %의 확률로 필터링 대상입니다.
#  옵션 펼침 display:block  : 20.5 %의 확률로 필터링 대상입니다.
#
# 							   : 22.2 %의 확률로 필터링 대상입니다.
#
# 							   : 22.2 %의 확률로 필터링 대상입니다.
#
# 							   : 22.2 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘명 : 22.2 %의 확률로 필터링 대상입니다.
# 닉네임 : 22.2 %의 확률로 필터링 대상입니다.
# 태그 : 22.2 %의 확률로 필터링 대상입니다.
# ul_selectric($('#f_sch_dccon .select_arraybox'), 'type' , 'title'); : 22.2 %의 확률로 필터링 대상입니다.
#
# 							   : 22.2 %의 확률로 필터링 대상입니다.
#
# 						   : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							   : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 검색 : 21.3 %의 확률로 필터링 대상입니다.
#
# 								   : 22.2 %의 확률로 필터링 대상입니다.
#
# 								 : 22.2 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
#
# 								   : 22.2 %의 확률로 필터링 대상입니다.
#
# 									   : 22.2 %의 확률로 필터링 대상입니다.
#
# 									 : 22.2 %의 확률로 필터링 대상입니다.
# 검색 : 21.3 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				   : 22.2 %의 확률로 필터링 대상입니다.
#
# 					   : 22.2 %의 확률로 필터링 대상입니다.
#
# 					   : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 일간 인기 디시콘 : 21.4 %의 확률로 필터링 대상입니다.
# 주간 인기 디시콘 : 21.4 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
# 인기 디시콘 : 21.4 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
#
# 							  : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 이전 : 21.3 %의 확률로 필터링 대상입니다.
#
# 							 : 22.2 %의 확률로 필터링 대상입니다.
#
# 						 : 22.2 %의 확률로 필터링 대상입니다.
# 다음 : 21.8 %의 확률로 필터링 대상입니다.
#
# 				{{each(i,item) list}}
# 				{{if parseInt(i % 5) == 0}}
# 				<ul class="dccon_shop_list clear ${addclass}" style="display:none;">
# 				{{/if}}
# 					<li>
# 					  <a class="link_product" href="javascript:;" >
# 						<img class="thumb_img written_dccon" src="${main_img_url}" alt="${title}" width="100" height="100">
# 						<strong class="dcon_name">${title}</strong>
# 						<span class="dcon_seller">${nick_name}</span>
# 						<span class="dcon_cash">만두 ${price}개</span>
# 						<span class="dcon_frame red_brd div_package" reqpath="/dccon" data-type="wrLayer"></span>
# 					  </a>
# 					</li>
# 				{{if parseInt(i % 5) == 4}}
# 				</ul>
# 				{{/if}}
# 				{{/each}}
# 				 : 27.1 %의 확률로 필터링 대상입니다.
#
# 					 : 22.2 %의 확률로 필터링 대상입니다.
#
# 				 : 22.2 %의 확률로 필터링 대상입니다.
# 로 검색된 디시콘이 없습니다. : 13.7 %의 확률로 필터링 대상입니다.
# [ : 22.2 %의 확률로 필터링 대상입니다.
# ] : 22.2 %의 확률로 필터링 대상입니다.
# 디시콘 더보기 : 71.4 %의 확률로 필터링 대상입니다.
#
# 			 : 22.2 %의 확률로 필터링 대상입니다.
#
# 		    : 22.2 %의 확률로 필터링 대상입니다.
#
# 		  : 22.2 %의 확률로 필터링 대상입니다.
#
# <div class="pop_wrap type3" id = "package_detail" style="left: 109px;top:20px;">
#  <div class="pop_content dccon_popinfo">
# 	 <div class="pop_head clear">
# 		<h3 >디시콘 정보</h3>
# 	</div>
# 	<div class="info_viewbox clear">
# 		<div class="info_viewimg">
# 		<img src="//dcimg5.dcinside.com/dccon.php?no=${info['main_img_path']}" alt="${info['title']}" width="140" height="140">
# 		</div>
# 		<div class="info_viewtxt">
# 		<div class="viewtxt_top clear">
# 			<h4 class="font_blue con_title">${info['title']}</h4>
# 			<span class="font_red">(금액: 만두 ${info['mandoo']}개)</span>
# 			{{if info['register']}}
# 			<span class="useday fr">남은 사용일: -일</span>
# 			{{else (info['residual']) }}
# 			<span class="useday fr">남은 사용일: ${info['residual']}일</span>
# 			{{else}}
# 			<button type="button" class="btn_blue small btn_buy" reqpath="/dccon">구매하기</button>
# 			{{/if}}
# 		</div>
# 		<div class="viewtxt_cont">
# 			<p class="inner_txt">
# 			${info['description']}
# 			</p>
# 			<div class="inner_info">
# 			<span class="tbox">제작</span>
# 			<span class="seller_name">${info['seller_name']}</span>
# 			<span class="makeday">${info['reg_date_short']}</span>
# 			</div>
# 			<div class="inner_info">
# 			<span class="tbox">태그</span>
# 			<span class="seller_name">
# 			{{each(i,item) tags}}
# 			{{if i != 0}},{{/if}}
# 			${tag}
# 			{{/each}}
# 			</span>
# 			</div>
# 		</div>
# 		</div>
# 	</div>
# 	<!-- dccon_list_wrap -->
# 	<div class="dccon_list_wrap clear">
# 	 <!-- 디시콘 리스트 dccon_list_box -->
# 	<div class="dccon_list_box popinfo">
# 		<ul class="dccon_list clear">
# 		{{each detail}}
# 			<li><span class="img_dccon"><img src="//dcimg5.dcinside.com/dccon.php?no=${path}" alt="${title}" title ="${title}"></span></li>
# 		{{/each}}
# 		</ul>
# 	</div>
# 	<!-- //디시콘 리스트 dccon_list_box -->
# 	</div>
# 	<!-- //dccon_list_wrap -->
# 	<div class="dccon_infobox">
# 		<p>유료 디시콘은 구매 후 1년 동안 사용 가능하며, 환불이 불가합니다.</p>
# 		<p>음란물을 디시콘으로 등록하는 경우 사이버수사대에 즉각 신고합니다.</p>
# 		<p>서비스 이용에 부적절하거나, 저작권에 위반된 저작물일 경우 별도 통보 없이 판매중지될 수 있습니다.</p>
# 	</div>
# 	</div>
#  <button type="button" class="poply_bgblueclose package_close" ><span class="blind">디시콘 정보 레이어 닫기</span><em class="sp_img icon_bgblueclose"></em></button>
#
#  <!-- 디시콘 구매하기 레이어팝업 -->
#  <div class="pop_wrap type3" style="left:136px;top:197px;display:none" id ="package_buy">
# 	 <div class="pop_content dccon_buy">
# 	 <div class="pop_head"><h3>구매하기</h3></div>
# 	 <div class="buy_info_box">
# 		 <dl class="buy_info">
# 		 <dt class="tit">디시콘명</dt>
# 		 <dd class="cont"><b class="font_red title"></b></dd>
# 		 </dl>
# 		 <dl class="buy_info">
# 		 <dt class="tit">보유만두</dt>
# 		 <dd class="cont user_cash"></dd>
# 		 </dl>
# 		 <dl class="buy_info">
# 		 <dt class="tit">차감만두</dt>
# 		 <dd class="cont use_cash"></dd>
# 		 </dl>
# 		 <dl class="buy_info">
# 		 <dt class="tit"><label for="pw">비밀번호</label></dt>
# 		 <dd class="cont pw"><input type="password" class="intxt" id="password" autocomplete="new-password" ></dd>
# 		 </dl>
# 	 </div>
# 	 <div class="btn_box">
# 		 <button type="button" class="btn_grey small cancel">취소</button>
# 		 <button type="button" class="btn_blue small payments">결제</button>
# 	 </div>
# 	 </div>
# 	 <button type="button" class="poply_bgblueclose"><span class="blind">알림 설정 레이어 닫기</span><em class="sp_img icon_bgblueclose"></em></button>
#  </div>
#  <!-- //디시콘 구매하기 레이어팝업 -->
#
#  <!-- 디시콘 신고하기 레이어팝업 -->
#  <div class="pop_wrap type3" id = "package_singo" style="left:136px;top:197px;display:none">
# 	 <div class="pop_content dccon_report">
# 	 <div class="pop_head"><h3>신고하기</h3></div>
# 	 <div class="dcconpop_cont">
# 		 <textarea title="신고내용 입력" class="dccon_txtarea" placeholder="내용입력"></textarea>
# 		 <div class="fileup_box clear">
# 		 <input type="text" class="fileup_name" placeholder="jpg, zip파일 / 5M이하">
# 		 <div class="fileup_btn_box">
# 			 <label for="input_file" class="fileup_btn">파일첨부</label>
# 			 <input type="file" id="input_file" class="fileup_hidden">
# 		 </div>
# 		 </div>
# 	 </div>
# 	 <div class="btn_box">
# 		 <button type="button" class="btn_grey small">취소</button>
# 		 <button type="button" class="btn_blue small">등록</button>
# 	 </div>
# 	 </div>
# 	 <button type="button" class="poply_bgblueclose"><span class="blind">알림 설정 레이어 닫기</span><em class="sp_img icon_bgblueclose"></em></button>
#  </div>
#  <!-- //디시콘 신고하기 레이어팝업 -->
#
#  <!-- 디시콘 판매중지 신청 레이어팝업 -->
#  <div class="pop_wrap type3" id ="package_stop_sale" style="left:136px;top:197px;display:none">
# 	 <div class="pop_content dccon_stop">
# 	 <div class="pop_head"><h3>판매중지 신청</h3></div>
# 	 <div class="dcconpop_cont">
# 		 <textarea title="판매중지 신청 사유 입력" class="dccon_txtarea" placeholder="내용입력" name ="memo" id ="memo"></textarea>
# 	 </div>
# 	 <div class="btn_box">
# 		 <button type="button" class="btn_grey small cancel">취소</button>
# 		 <button type="button" class="btn_blue small request">등록</button>
# 	 </div>
# 	 </div>
# 	 <button type="button" class="poply_bgblueclose cancel"><span class="blind">알림 설정 레이어 닫기</span><em class="sp_img icon_bgblueclose"></em></button>
#  </div>
#  <!-- //디시콘 판매중지 신청 레이어팝업 -->
#
# </div>
#  : 97.7 %의 확률로 필터링 대상입니다.
#
# 	<div class="alarmPopup pop_wrap type1 fixed" style="right:30px;bottom:30px;display:none">
# 	  <div class="pop_content one_noticewrap">
# 		<a href="${link}" class="one_notice_txt" onclick="alarmReadOk(${idx})">
# 		  <span class="new"><em class="blind">NEW</em><em class="sp_img icon_new"></em></span>${prefix}{{if type == 'manager'}}]{{/if}} ${content}
# 		</a>
# 		<button type="button" class="poply_close" onclick="alarmReadOk(${idx});$('.alarmPopup').remove()"><span class="blind">알림 레이어 닫기</span><em class="sp_img icon_blueclose"></em></button>
# 	  </div>
# 	</div>
#    : 32.4 %의 확률로 필터링 대상입니다.
#
#   window._taboola = window._taboola || [];
#   _taboola.push({flush: true});
#    : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-5149721-11']);
# 	  _gaq.push(['_setDomainName', 'dcinside.com']);
# 	  _gaq.push(['_setAllowLinker', true]);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-5149721-39']);
# 	  _gaq.push(['_setDomainName', 'dcinside.com']);
# 	  _gaq.push(['_setAllowLinker', true]);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	 : 22.2 %의 확률로 필터링 대상입니다.
#
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "f92eaecbc22aac";
# try { wcs_do();} catch(err) {}
#  : 22.2 %의 확률로 필터링 대상입니다.
# 127.0.0.1 - - [10/Apr/2021 15:24:42] "POST /use_model HTTP/1.1" 200 -
